# %% [markdown]
# # Численные методы
#
# ## Лабораторная работа 2
#
# ### Вариант 1
# ### Студент: Тимофеенко Никита

# %% [markdown]
# #### Задание 1(А, Б, В).
#
# Метод Эйлера - численный метод решения систем обыкновенных ДУ. Основан на аппроксимации интегральной кривой (график решения геометрически неопределенного интеграла) кусочно - линейной функцией (ломаная Эйлера).

# %%
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt


def f(x, y):
    """ Определяем правую часть уравнения  """
    return 2 * x


y0 = [1]                                        # начальные условия для аналитического решения
x_span = [0, 10]                                # интервал для аналитического решения
result = solve_ivp(f, x_span, y0)               # ответ аналитического решения


y0_Euler = 1                                    # для решения методом Эйлера
h = 0.0001                                      # шаг приближения
x = np.arange(0, 10 + h, h)                     # разбиваем интервал на шаги
y = np.zeros_like(x)                            # нужен для сохранения всех значений y_i
y[0] = y0_Euler                                 # начальное значение, которое сохраняем в нулевом элементе массива

for i in range(0, len(x) - 1):
    y[i + 1] = y[i] + h * f(x[i], y[i])

plt.plot(result.t, result.y[0], label='Аналитическое решение')
plt.xlabel('x')
plt.ylabel('y')


plt.plot(x, y, label='Метод Эйлера')
plt.legend()

plt.show()
print(f'x = {result.t[-1]}, y = {result.y[0][-1]}')
print(f'Метод Эйлера: x = {x[-1]}, y = {y[-1]}')
# Out:
# x = 10.0, y = 100.99999999999999
# Метод Эйлера: x = 10.0, y = 100.99900000000001

# %% [markdown]
# #### Задание 1(Г, Д).

# %%
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt


def f(x, y):
	""" Определяем правую часть уравнения  """
	return 2 * x


y0 = [1]
x_span = [0, 10]
result = solve_ivp(f, x_span, y0)
print(f' Solx = {result.t[-1]}, y = {result.y[0][-1]}')
# Out:
# x = 10.0, y = 100.99999999999999
